# %% [markdown]
# **Import Library**

# %% [markdown]
# ### ***Install Library***

# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.3 MB/s eta 0:00:00
# ...

# %%
# !pip install pandas
# !pip install numpy

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
#scraper all available reviews
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
'com.google.android.youtube',
lang='id',
country='id',
sort=Sort.NEWEST,
count=10000,
filter_score_with=None
)

# %% [markdown]
# **Show Data yang sudah di crawling**

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review']) #nama file bebas
df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))
df_busu.tail()
# Out:
#                                   reviewId            userName  \
# 9995  5be1817d-bbb5-45c1-9070-387ebf24eb6e  Kusrsih Hadikusuma
# 9996  1ba79de3-1081-4643-a778-06b564592cde     Jajang Suryaman
# 9997  3425ba51-fd40-4333-89b0-5390b35cf40f     Gibran123 Jedor
# 9998  f653a8ab-c88f-4691-82e3-4962c77e5f4a      Muhammad Habib
# 9999  40383ed1-43ad-4bba-90f7-98eb2d1ea0c8      Cerita 1 Menit
#
#                                               userImage  \
# 9995  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9996  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 9999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                 content  score  thumbsUpCount  \
# 9995  Kenapa makin kesini aplikasi ini bikin kesal g...      5              0
# 9996                                              sehat      4              0
# ...

# %%
len(df_busu.index)
# Out:
# 10000

# %% [markdown]
# **Ambil data yang dibutuhkan**

# %%
df_busu[['userName', 'score', 'at', 'content']].tail()
# Out:
#                 userName  score                  at  \
# 9995  Kusrsih Hadikusuma      5 2026-05-18 19:41:19
# 9996     Jajang Suryaman      4 2026-05-18 19:19:48
# 9997     Gibran123 Jedor      5 2026-05-18 19:16:44
# 9998      Muhammad Habib      1 2026-05-18 18:26:35
# 9999      Cerita 1 Menit      1 2026-05-18 18:24:41
#
#                                                 content
# 9995  Kenapa makin kesini aplikasi ini bikin kesal g...
# 9996                                              sehat
# 9997                                               bgus
# 9998  kenapa saat ini YouTube punya peraturan yg tid...
# 9999  bro, gua bangun channel dari 0, sampai sekaran...

# %%
my_df= df_busu[['userName', 'score', 'at', 'content']]

# %%
#simpan dataset ke dalam file
my_df.to_csv("Dataset_YouTube.csv", index=False)
